# %%
import pygame
import pygame.midi
import mido
import sys
import time
import numpy as np
from collections import defaultdict
import sounddevice as sd
import soundfile as sf
import argparse
import os
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.14)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pandas as pd

# %%
midi_file = mido.MidiFile("./Midi_files/avengers.mid")

# %%
pd.DataFrame(midi_file)
# Out:
#                                                       0
# 0     MetaMessage('time_signature', numerator=4, den...
# 1        MetaMessage('set_tempo', tempo=500000, time=0)
# 2     MetaMessage('track_name', name='Elec. Piano (C...
# 3             program_change channel=0 program=0 time=0
# 4          note_on channel=0 note=55 velocity=50 time=0
# ...                                                 ...
# 2384       note_off channel=0 note=76 velocity=0 time=0
# 2385       note_off channel=0 note=64 velocity=0 time=0
# 2386       note_off channel=0 note=24 velocity=0 time=0
# 2387       note_off channel=0 note=36 velocity=0 time=0
# 2388                MetaMessage('end_of_track', time=0)
#
# [2389 rows x 1 columns]

# %%
midi_file.tracks[0][4].dict()
# Out:
# {'type': 'note_on', 'time': 0, 'note': 55, 'velocity': 50, 'channel': 0}

# %%
midi_file.tracks[0][5].dict()
# Out:
# {'type': 'note_on', 'time': 0, 'note': 67, 'velocity': 50, 'channel': 0}

# %%
midi_file
# Out:
# MidiFile(type=0, ticks_per_beat=384, tracks=[
#   MidiTrack([
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('set_tempo', tempo=500000, time=0),
#     MetaMessage('track_name', name='Elec. Piano (Classic)', time=0),
#     Message('program_change', channel=0, program=0, time=0),
#     Message('note_on', channel=0, note=55, velocity=50, time=0),
#     Message('note_on', channel=0, note=67, velocity=50, time=0),
#     Message('note_on', channel=0, note=43, velocity=50, time=0),
#     Message('note_on', channel=0, note=50, velocity=50, time=0),
#     Message('note_off', channel=0, note=50, velocity=0, time=96),
#     Message('note_off', channel=0, note=43, velocity=0, time=0),
#     Message('note_off', channel=0, note=67, velocity=0, time=0),
#     Message('note_off', channel=0, note=55, velocity=0, time=0),
#     Message('note_on', channel=0, note=50, velocity=50, time=0),
# ...
